# %% [markdown]
# # Evaluation

# %%
from time import time
from recommender_system import RecommenderSystem
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
minFreqs = [0,1]
recommendationLengths = [10]
artistSims = ['tags', 'users']
maxReferenceArtists = [1,3,5]
kneighborhood = [1, 2, None]
maxSimilarUsers = [1, 3]

for minFreq in minFreqs:
    e = RecommenderSystem(minFreqTag=minFreq)
    for recommendationLength in recommendationLengths:
        for artistSim in artistSims:
            for refArtists in maxReferenceArtists:
                for k in kneighborhood:
                    for simUsers in maxSimilarUsers:
                        e.recommendation_evaluation(maxReferenceArtists=refArtists, kneighborhood=k, maxSimilarUsers=simUsers, recommendationLength=recommendationLength, relevanceLength=None, relevanceAccum=0.95, numUsers=10000, artistSim=artistSim)
# Out:
# __________________________________________________________
#
# FT=0,kN=1,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.646809. Std: 2.087893.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.351064. Std: 1.843663.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.467553. Std: 2.020904.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.325000. Std: 1.816067.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.095213. Std: 1.993868.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.150000. Std: 1.786429.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.670940. Std: 2.086702.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.418269. Std: 1.880440.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.612179. Std: 2.023954.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.485577. Std: 1.870202.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.371261. Std: 2.027979.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.437500. Std: 1.839251.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.618153. Std: 2.027669.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.365199. Std: 1.846945.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.578947. Std: 1.986244.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.479055. Std: 1.840685.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.417293. Std: 1.953372.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.487111. Std: 1.854421.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.742021. Std: 2.707346.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 4.165957. Std: 2.713463.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# /Users/guillermobernardezgil/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Median: 3.000000. Mean: 3.498936. Std: 2.698699.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 4.037766. Std: 2.677956.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.922872. Std: 2.727111.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.650532. Std: 2.745925.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.616453. Std: 2.634280.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 4.017094. Std: 2.649328.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.470085. Std: 2.610212.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 4.018162. Std: 2.608683.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.142628. Std: 2.659939.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 3.842415. Std: 2.644793.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.470462. Std: 2.543064.
#
# __________________________________________________________
#
# FT=0,kN=1,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 3.798604. Std: 2.555872.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.324382. Std: 2.483249.
#
# __________________________________________________________
#
# FT=0,kN=2,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 3.872180. Std: 2.542187.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.112245. Std: 2.459505.
#
# __________________________________________________________
#
# FT=0,kN=None,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 3.827605. Std: 2.540505.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.500000. Mean: 2.827660. Std: 2.234183.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.586702. Std: 1.975363.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.620213. Std: 2.154514.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.553723. Std: 1.953526.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.242553. Std: 2.135241.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.389362. Std: 1.934979.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 2.854167. Std: 2.224474.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.673611. Std: 2.032006.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.762286. Std: 2.144514.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.736111. Std: 2.034379.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.526175. Std: 2.164782.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.688034. Std: 1.999441.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.772825. Std: 2.147227.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.604726. Std: 2.025227.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.705156. Std: 2.087908.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.722879. Std: 1.982063.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.523093. Std: 2.056467.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 2.739527. Std: 1.976319.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.742021. Std: 2.707346.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 4.165957. Std: 2.713463.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.498936. Std: 2.698699.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 4.037766. Std: 2.677956.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=1,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.929255. Std: 2.726699.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=3,RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.640957. Std: 2.741005.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.616453. Std: 2.634280.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 4.017094. Std: 2.649328.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.470085. Std: 2.610212.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 4.018162. Std: 2.608683.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=1,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.143697. Std: 2.659480.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=3,RA=3
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 3.830662. Std: 2.641439.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.470462. Std: 2.543064.
#
# __________________________________________________________
#
# FT=1,kN=1,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 3.798604. Std: 2.555872.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.324382. Std: 2.483249.
#
# __________________________________________________________
#
# FT=1,kN=2,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 3.872180. Std: 2.542187.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=1,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 3.000000. Mean: 3.108485. Std: 2.456287.
#
# __________________________________________________________
#
# FT=1,kN=None,SU=3,RA=5
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 4.000000. Mean: 3.832438. Std: 2.543470.

# %%
for j in range(10):
    for i in range(100):
        if i > 10: break;

# %%
j
# Out:
# 9

# %%
e = RecommenderSystem.instance()

recommendationLengths = [1,5,20]
maxReferenceArtists = [1,3,5]
kneighborhood = [1, 2, None]
maxSimilarUsers = [1, 5]  #(for k=1, 2, 5) 

for recommendationLength in recommendationLengths:
    for refArtists in maxReferenceArtists:
        for k in kneighborhood:
            for simUsers in maxSimilarUsers:
                e.recommendation_evaluation(maxReferenceArtists=refArtists, kneighborhood=k, maxSimilarUsers=simUsers, recommendationLength=recommendationLength, relevanceLength=None, relevanceAccum=0.95, numUsers=10000)
# Out:
# __________________________________________________________
#
# kN=1, SU=1, RA=1, RL=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.269681. Std: 0.443794.
#
# __________________________________________________________
#
# kN=1, SU=5, RA=1, RL=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.192553. Std: 0.394305.
#
# __________________________________________________________
#
# kN=2, SU=1, RA=1, RL=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.254255. Std: 0.435442.
#
# __________________________________________________________
#
# kN=2, SU=5, RA=1, RL=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.194149. Std: 0.395544.
#
# __________________________________________________________
#
# kN=None, SU=1, RA=1, RL=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.227660. Std: 0.419322.
#
# __________________________________________________________
#
# kN=None, SU=5, RA=1, RL=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.194681. Std: 0.395955.
#
# __________________________________________________________
#
# kN=1, SU=1, RA=3, RL=1
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.271368. Std: 0.444665.
#
# __________________________________________________________
#
# kN=1, SU=5, RA=3, RL=1
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.213141. Std: 0.409526.
#
# __________________________________________________________
#
# kN=2, SU=1, RA=3, RL=1
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.293803. Std: 0.455503.
#
# __________________________________________________________
#
# kN=2, SU=5, RA=3, RL=1
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.203526. Std: 0.402620.
#
# __________________________________________________________
#
# kN=None, SU=1, RA=3, RL=1
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.273504. Std: 0.445757.
#
# __________________________________________________________
#
# kN=None, SU=5, RA=3, RL=1
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.207265. Std: 0.405347.
#
# __________________________________________________________
#
# kN=1, SU=1, RA=5, RL=1
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.275510. Std: 0.446771.
#
# __________________________________________________________
#
# kN=1, SU=5, RA=5, RL=1
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.207841. Std: 0.405762.
#
# __________________________________________________________
#
# kN=2, SU=1, RA=5, RL=1
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.286788. Std: 0.452262.
#
# __________________________________________________________
#
# kN=2, SU=5, RA=5, RL=1
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.201396. Std: 0.401043.
#
# __________________________________________________________
#
# kN=None, SU=1, RA=5, RL=1
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.287863. Std: 0.452767.
#
# __________________________________________________________
#
# kN=None, SU=5, RA=5, RL=1
#
# Evaluation performed over 1862 users; 30 selected users did not have enough relevant artists to be evaluated
# Median: 0.000000. Mean: 0.197100. Std: 0.397808.
#
# __________________________________________________________
#
# kN=1, SU=1, RA=1, RL=5
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 1.000000. Mean: 1.377128. Std: 1.254697.
#
# __________________________________________________________
#
# kN=1, SU=5, RA=1, RL=5
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 1.000000. Mean: 1.044149. Std: 1.067742.
#
# __________________________________________________________
#
# kN=2, SU=1, RA=1, RL=5
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# /Users/guillermobernardezgil/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Median: 1.000000. Mean: 1.290957. Std: 1.230777.
#
# __________________________________________________________
#
# kN=2, SU=5, RA=1, RL=5
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 1.000000. Mean: 0.994149. Std: 1.050060.
#
# __________________________________________________________
#
# kN=None, SU=1, RA=1, RL=5
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 1.000000. Mean: 1.130319. Std: 1.197753.
#
# __________________________________________________________
#
# kN=None, SU=5, RA=1, RL=5
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 1.000000. Mean: 0.968085. Std: 1.042217.
#
# __________________________________________________________
#
# kN=1, SU=1, RA=3, RL=5
#
# Evaluation performed over 1872 users; 20 selected users did not have enough relevant artists to be evaluated
# Median: 1.000000. Mean: 1.416667. Std: 1.261486.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-373925127372> in <module>()
#      10         for k in kneighborhood:
#      11             for simUsers in maxSimilarUsers:
# ---> 12                 e.recommendation_evaluation(maxReferenceArtists=refArtists, kneighborhood=k, maxSimilarUsers=simUsers, recommendationLength=recommendationLength, relevanceLength=None, relevanceAccum=0.95, numUsers=10000)
#
# /Users/guillermobernardezgil/Documents/Dropbox/Master in Artificial Intelligence/MAI 2/music_recommender/src/recommender_system.py in recommendation_evaluation(self, maxReferenceArtists, recommendationLength, relevanceLength, kneighborhood, maxSimilarUsers, relevanceAccum, numUsers)
#     105         noValid = 0
#     106         for user in self.users_id[0:min(numUsers, len(self.users_id))]:
# --> 107             numberOfRecoveries = self.user_recommendation_evaluation(self.key_user(user), maxReferenceArtists=maxReferenceArtists, recommendationLength=recommendationLength, relevanceLength=relevanceLength, kneighborhood=kneighborhood, maxSimilarUsers=maxSimilarUsers, relevanceAccum=relevanceAccum)
#     108             if numberOfRecoveries >= 0:
#     109                 recoveries.append(numberOfRecoveries)
#
# /Users/guillermobernardezgil/Documents/Dropbox/Master in Artificial Intelligence/MAI 2/music_recommender/src/recommender_system.py in user_recommendation_evaluation(self, referenceUser, maxReferenceArtists, recommendationLength, relevanceLength, kneighborhood, maxSimilarUsers, relevanceAccum)
#      87
#      88         # We get the recommendation of the user considering only their 'maxReferenceArtists' most listened artists
# ---> 89         recommendedArtists = self.recommendation(referenceUser, kneighborhood=kneighborhood, maxSimilarUsers=maxSimilarUsers, relevanceAccum=relevanceAccum, showRecommendation=False)
#      90         # We keep the most similar artists found in the recommendation
#      91         recommendedArtists = set([recommendedArtists[i][0] for i in range(min(recommendationLength, len(recommendedArtists)))])
#
# /Users/guillermobernardezgil/Documents/Dropbox/Master in Artificial Intelligence/MAI 2/music_recommender/src/recommender_system.py in recommendation(self, referenceUser, kneighborhood, maxSimilarUsers, relevanceAccum, showRecommendation, recommendationLength)
#      49             candidateArtists = [artist for artist in candidateArtists if artist not in artistsAlreadyConsidered]
#      50             artistsAlreadyConsidered += candidateArtists
# ---> 51             candidateArtists = self.get_scores_for_candidate_artists(relevantArtists, candidateArtists)
#      52
#      53             # We combine these candidates with the previously found ones
#
# /Users/guillermobernardezgil/Documents/Dropbox/Master in Artificial Intelligence/MAI 2/music_recommender/src/recommender_system.py in get_scores_for_candidate_artists(self, referenceArtists, candidateArtists)
#     224         reference artist'''
#     225         return [(artist, self.get_artist_similarities(artist, referenceArtists)[0][1])
# --> 226                 for artist in candidateArtists]
#     227
#     228     def combine_lists_of_candidate_artists(self, list1, list2):
#
# /Users/guillermobernardezgil/Documents/Dropbox/Master in Artificial Intelligence/MAI 2/music_recommender/src/recommender_system.py in get_artist_similarities(self, centralNode, listOfNodes)
#     196         '''given a reference artist and a list of artists, computes the similarity
#     197         of each element of the list with respect to the reference artist'''
# --> 198         artistSim = [(node, self.get_artist_artist_similarity(centralNode, node)) for node in listOfNodes]
#     199         return sorted(artistSim, key=self.get_ordering_key, reverse=True)
#     200
#
# /Users/guillermobernardezgil/Documents/Dropbox/Master in Artificial Intelligence/MAI 2/music_recommender/src/recommender_system.py in get_artist_artist_similarity(self, node1, node2)
#     175                 return self.artist_similarities_tags[idx1, idx2]
#     176             else:
# --> 177                 return self.artist_similarities_tags[idx2, idx1]
#     178         else:
#     179             cluster1 = set(self.artist_tags_iter(node1))
#
# /Users/guillermobernardezgil/anaconda/lib/python2.7/site-packages/scipy/sparse/lil.pyc in __getitem__(self, index)
#     252                 v = _csparsetools.lil_get1(self.shape[0], self.shape[1],
#     253                                            self.rows, self.data,
# --> 254                                            i, j)
#     255                 return self.dtype.type(v)
#     256
#
# KeyboardInterrupt:

# %%
t0= time()
e.recommendation('u_1200')
print time()-t0
# Out:
# USER: u_1200
#
# RELEVANT ARTISTS FOR THE USER: ['Duran Duran', 'John Frusciante', 'The Rolling Stones', 'Bijelo Dugme', 'Oasis', 'Indexi', 'Manic Street Preachers', 'Divlje Jagode', 'The Beatles', 'Prljavo Kazali\xc5\xa1te', 'Red Hot Chili Peppers', 'Muse', 'Dire Straits', 'The Killers', 'Depeche Mode', 'U2', 'Sting', 'Johnny Cash', 'Eric Clapton', 'Bob Dylan', '\xc4\x90or\xc4\x91e Bala\xc5\xa1evi\xc4\x87', 'Bruce Springsteen', 'Zabranjeno Pu\xc5\xa1enje', 'Coldplay', 'Mark Knopfler', 'Toto', 'Andy Taylor', 'The Police', 'Gibonni', 'Blur', "Blackmore's Night", 'Suede', 'Pink Floyd', 'Michael Jackson', 'Crvena Jabuka', 'The Smiths', 'David Bowie', 'Led Zeppelin', 'Kings of Leon']
#
# RECOMMENDED ARTISTS: ['Color Theory', 'Stone Gossard', 'Gotthard', 'Brad', 'Parni Valjak', 'PJ Harvey', 'The Human League', 'Placebo', 'Arctic Monkeys', 'The Who']
# 0.729307889938

# %%
e.recommendation('u_511')
# Out:
# USER: u_511
#
# RELEVANT ARTISTS FOR THE USER: ['Radiohead', 'The Smashing Pumpkins', 'Arcade Fire', 'Wilco', 'Nirvana', 'Queens of the Stone Age', 'The Strokes', 'My Bloody Valentine', 'Rage Against the Machine', 'Soundgarden', 'Jonny Greenwood', 'Pearl Jam', 'Sonic Youth', 'Coldplay', 'Pixies', 'Fleet Foxes', 'Rise Against', 'The White Stripes', 'Kings of Leon', 'Thom Yorke', 'The Black Keys', 'Pink Floyd', 'Animal Collective', 'Foo Fighters', 'Hans Zimmer', 'The Who', 'The Dead Weather']
#
# RECOMMENDED ARTISTS: ['Wolfmother', 'Interpol', 'Cat Power', 'Mew', 'Muse', 'Stone Temple Pilots', 'The Jesus and Mary Chain', 'Spoon', 'Deftones', 'The Offspring']
# [('a_3475', 0.3170731707317073),
#  ('a_225', 0.3150684931506849),
#  ('a_1424', 0.28169014084507044),
#  ('a_170', 0.2777777777777778),
#  ('a_190', 0.2757201646090535),
#  ('a_860', 0.2647058823529412),
#  ('a_3279', 0.2558139534883721),
#  ('a_434', 0.2558139534883721),
#  ('a_512', 0.25),
#  ('a_1406', 0.25),
#  ('a_517', 0.25),
#  ('a_1202', 0.2463768115942029),
#  ('a_735', 0.24074074074074073),
#  ('a_1510', 0.23595505617977527),
#  ('a_3739', 0.23529411764705882),
#  ('a_173', 0.23300970873786409),
#  ('a_8042', 0.22857142857142856),
#  ('a_1639', 0.22784810126582278),
#  ('a_366', 0.22641509433962265),
#  ('a_4115', 0.22580645161290322),
#  ('a_227', 0.2222222222222222),
#  ('a_203', 0.21978021978021978),
#  ('a_2346', 0.21904761904761905),
#  ('a_421', 0.21875),
#  ('a_220', 0.2153846153846154),
#  ('a_853', 0.21428571428571427),
#  ('a_1118', 0.21428571428571427),
#  ('a_4179', 0.21052631578947367),
#  ('a_205', 0.20930232558139536),
#  ('a_898', 0.20634920634920634),
#  ('a_4435', 0.20512820512820512),
#  ('a_72', 0.20414201183431951),
#  ('a_4074', 0.2),
#  ('a_1044', 0.2),
#  ('a_159', 0.19907407407407407),
#  ('a_207', 0.1958762886597938),
#  ('a_599', 0.19574468085106383),
#  ('a_6724', 0.1951219512195122),
#  ('a_4359', 0.19444444444444445),
#  ('a_10040', 0.1935483870967742),
#  ('a_81', 0.1912568306010929),
#  ('a_1090', 0.18947368421052632),
#  ('a_715', 0.1891891891891892),
#  ('a_1151', 0.18867924528301888),
#  ('a_212', 0.1875),
#  ('a_198', 0.18478260869565216),
#  ('a_453', 0.18181818181818182),
#  ('a_1513', 0.1794871794871795),
#  ('a_428', 0.1791044776119403),
#  ('a_9344', 0.17857142857142858),
#  ('a_3797', 0.17647058823529413),
#  ('a_59', 0.17424242424242425),
#  ('a_2582', 0.17073170731707318),
#  ('a_10385', 0.1702127659574468),
#  ('a_166', 0.16666666666666666),
#  ('a_432', 0.16666666666666666),
#  ('a_498', 0.16666666666666666),
#  ('a_233', 0.16666666666666666),
#  ('a_51', 0.16312056737588654),
#  ('a_1249', 0.16071428571428573),
#  ('a_924', 0.15789473684210525),
#  ('a_238', 0.15555555555555556),
#  ('a_1778', 0.15384615384615385),
#  ('a_959', 0.15346534653465346),
#  ('a_1985', 0.14942528735632185),
#  ('a_1772', 0.14814814814814814),
#  ('a_2606', 0.14035087719298245),
#  ('a_706', 0.13978494623655913),
#  ('a_875', 0.136986301369863),
#  ('a_707', 0.13125),
#  ('a_10662', 0.1282051282051282),
#  ('a_3444', 0.125),
#  ('a_1109', 0.125),
#  ('a_2834', 0.125),
#  ('a_1110', 0.125),
#  ('a_1394', 0.1232876712328767),
#  ('a_1089', 0.12244897959183673),
#  ('a_56', 0.12244897959183673),
#  ('a_1817', 0.12121212121212122),
#  ('a_4848', 0.12),
#  ('a_917', 0.11165048543689321),
#  ('a_12496', 0.1111111111111111),
#  ('a_610', 0.1111111111111111),
#  ('a_176', 0.1111111111111111),
#  ('a_1810', 0.11),
#  ('a_620', 0.1076923076923077),
#  ('a_714', 0.09803921568627451),
#  ('a_3892', 0.09433962264150944),
#  ('a_16676', 0.08333333333333333),
#  ('a_5237', 0.08196721311475409),
#  ('a_705', 0.058823529411764705),
#  ('a_4349', 0.05555555555555555),
#  ('a_3310', 0.045454545454545456),
#  ('a_5154', 0.019230769230769232),
#  ('a_16675', 0.0)]

# %%
t0 = time()
e = RecommenderSystem.instance()

maxReferenceArtists = [1]
kneighborhood = [1, 2, 5, None]
maxSimilarUsers1 = [1, 5]  #(for k=1, 2, 5) 
maxSimilarUsers2 = [1, 5, 10, 50] #(for k=None)

for refArtists in maxReferenceArtists:
    for k in kneighborhood:
        maxSimilarUsers = maxSimilarUsers1 if k else maxSimilarUsers2
        for simUsers in maxSimilarUsers:
            e.recommendation_evaluation(maxReferenceArtists=refArtists, kneighborhood=k, maxSimilarUsers=simUsers, recommendationLength=10, relevanceLength=None, relevanceAccum=0.95, numUsers=10000)
# Out:
# __________________________________________________________
#
# kN=1, SU=1, RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.646809. Std: 2.087893.
#
# __________________________________________________________
#
# kN=1, SU=5, RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.133511. Std: 1.716858.
#
# __________________________________________________________
#
# kN=2, SU=1, RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.467553. Std: 2.020904.
#
# __________________________________________________________
#
# kN=2, SU=5, RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.061702. Std: 1.715828.
#
# __________________________________________________________
#
# kN=5, SU=1, RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.151596. Std: 1.987433.
#
# __________________________________________________________
#
# kN=5, SU=5, RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.048404. Std: 1.722287.
#
# __________________________________________________________
#
# kN=None, SU=1, RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 2.094149. Std: 1.993918.
#
# __________________________________________________________
#
# kN=None, SU=5, RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 2.000000. Mean: 1.963830. Std: 1.718724.
#
# __________________________________________________________
#
# kN=None, SU=10, RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 1.000000. Mean: 1.680319. Std: 1.538318.
#
# __________________________________________________________
#
# kN=None, SU=50, RA=1
#
# Evaluation performed over 1880 users; 12 selected users did not have enough relevant artists to be evaluated
# Median: 1.000000. Mean: 1.052660. Std: 1.215544.

# %%
print time()-t0
# Out:
# 8558.22701192

# %%
import pandas as pd
artists=pd.read_table('../data/artists.dat')
tags=pd.read_table('../data/tags.dat')

# %%
def tagPreprocessing(tag):
    # write every tag in lower case
    tag = tag.lower()
    # remove punctuation marks, symbols, whitespaces
    punct_to_remove = list(' #%&\*+/<=>-\\^{|}~()[]:;\'`¡.,¿?!')  # + ['\r', '\n', '\t']
    for ch in punct_to_remove:
        tag = tag.replace(ch, '')
    return tag

def applyDictionaryTagIDs(tagID, dictionarytagIDs):
    try:
        return dictionarytagIDs[tagID]
    except Exception:
        return tagID

tags['tagValue'] = tags['tagValue'].map(lambda x: tagPreprocessing(x))

# %%
tags.shape
# Out:
# (11946, 2)

# %%
dictionaryTagIDs = {}
for indices in tags.groupby(['tagValue']).groups.values():
    for idx in indices:
        dictionaryTagIDs[tags['tagID'][idx]] = tags['tagID'][indices[0]]

# %%
tags = tags[tags['tagID'].isin(dictionaryTagIDs.values())]

# %%
tags.head()
# Out:
#    tagID          tagValue
# 0      1             metal
# 1      2  alternativemetal
# 2      3          gothrock
# 3      4        blackmetal
# 4      5        deathmetal

# %%
len(set(tags['tagValue']))
# Out:
# 11567

# %%
user_taggedartists=pd.read_table('../data/user_taggedartists.dat')
len(set(user_taggedartists['tagID']))
# Out:
# 9749

# %%
def applyDictionaryTagIDs(tagID, dictionarytagIDs):
    try:
        return dictionarytagIDs[tagID]
    except Exception:
        return tagID

# %%
user_taggedartists['tagID'] = user_taggedartists['tagID'].apply(lambda x: applyDictionaryTagIDs(x, dictionaryTagIDs))
len(set(user_taggedartists['tagID']))
# Out:
# 9437

# %%
a = user_taggedartists['tagID']

# %%
b=a.value_counts()
list(b[b>4].keys())
# Out:
# [73,
#  24,
#  79,
#  18,
#  81,
#  130,
#  19,
#  39,
#  78,
#  192,
#  195,
#  84,
#  71,
#  134,
#  72,
#  33,
#  1,
#  14,
#  352,
#  16,
#  127,
#  13,
#  181,
#  292,
#  187,
#  167,
#  17,
#  191,
#  386,
#  625,
#  735,
#  185,
#  387,
#  83,
#  184,
#  306,
#  21,
#  61,
#  109,
#  376,
#  103,
#  210,
#  216,
#  194,
#  275,
#  296,
#  363,
#  247,
#  182,
#  87,
#  829,
#  88,
#  15,
#  213,
#  238,
#  91,
#  47,
#  309,
#  285,
#  508,
#  180,
#  824,
#  850,
#  5,
#  49,
#  432,
#  169,
#  234,
#  177,
#  193,
#  86,
#  76,
#  176,
#  526,
#  178,
#  90,
#  85,
#  545,
#  364,
#  385,
#  179,
#  170,
#  105,
#  30,
#  346,
#  199,
#  611,
#  615,
#  570,
#  231,
#  121,
#  206,
#  730,
#  1911,
#  321,
#  228,
#  378,
#  541,
#  839,
#  308,
#  481,
#  391,
#  823,
#  311,
#  4,
#  229,
#  7,
#  445,
#  299,
#  370,
#  393,
#  32,
#  140,
#  693,
#  34,
#  242,
#  695,
#  424,
#  20,
#  1097,
#  575,
#  203,
#  89,
#  527,
#  23,
#  830,
#  139,
#  26,
#  935,
#  1071,
#  67,
#  75,
#  354,
#  724,
#  2,
#  601,
#  1354,
#  6,
#  1252,
#  826,
#  1447,
#  512,
#  2726,
#  511,
#  265,
#  319,
#  108,
#  640,
#  345,
#  741,
#  209,
#  2349,
#  188,
#  565,
#  836,
#  183,
#  249,
#  600,
#  190,
#  82,
#  848,
#  56,
#  80,
#  200,
#  405,
#  1492,
#  483,
#  1356,
#  825,
#  574,
#  662,
#  395,
#  1352,
#  608,
#  406,
#  1995,
#  186,
#  706,
#  1006,
#  230,
#  793,
#  27,
#  201,
#  1210,
#  396,
#  617,
#  360,
#  557,
#  69,
#  145,
#  1753,
#  447,
#  1627,
#  642,
#  1355,
#  208,
#  742,
#  564,
#  1754,
#  828,
#  781,
#  1365,
#  719,
#  46,
#  327,
#  1534,
#  98,
#  1358,
#  500,
#  347,
#  641,
#  528,
#  233,
#  713,
#  503,
#  356,
#  727,
#  743,
#  2139,
#  141,
#  626,
#  287,
#  1286,
#  799,
#  2115,
#  3375,
#  1538,
#  349,
#  1967,
#  1970,
#  59,
#  762,
#  784,
#  996,
#  253,
#  1478,
#  3673,
#  1735,
#  1812,
#  409,
#  831,
#  3577,
#  1353,
#  120,
#  22,
#  712,
#  5286,
#  1834,
#  2246,
#  159,
#  232,
#  505,
#  1222,
#  2191,
#  1237,
#  70,
#  197,
#  2785,
#  757,
#  189,
#  619,
#  2142,
#  9817,
#  235,
#  1727,
#  1368,
#  1372,
#  1495,
#  2244,
#  1100,
#  1096,
#  2068,
#  1445,
#  1539,
#  1074,
#  5818,
#  6170,
#  1357,
#  543,
#  2752,
#  394,
#  8303,
#  588,
#  889,
#  12287,
#  6628,
#  2140,
#  2118,
#  12209,
#  9820,
#  792,
#  6171,
#  1023,
#  855,
#  4328,
#  1098,
#  2063,
#  604,
#  6450,
#  702,
#  1348,
#  5819,
#  2700,
#  3507,
#  1833,
#  128,
#  4449,
#  507,
#  251,
#  9,
#  4847,
#  408,
#  568,
#  8061,
#  689,
#  885,
#  2805,
#  524,
#  315,
#  9425,
#  2336,
#  122,
#  302,
#  1680,
#  1858,
#  1722,
#  10534,
#  955,
#  1099,
#  2217,
#  6172,
#  1302,
#  6763,
#  636,
#  1671,
#  3539,
#  8503,
#  514,
#  8301,
#  1351,
#  227,
#  7253,
#  9819,
#  7797,
#  415,
#  494,
#  92,
#  7995,
#  11061,
#  12208,
#  4549,
#  6976,
#  895,
#  1797,
#  10585,
#  7996,
#  2233,
#  7938,
#  771,
#  8670,
#  1032,
#  797,
#  3536,
#  3242,
#  1889,
#  4356,
#  9821,
#  2511,
#  12029,
#  4897,
#  842,
#  4952,
#  7252,
#  44,
#  1102,
#  696,
#  160,
#  4141,
#  4289,
#  8302,
#  137,
#  513,
#  1208,
#  8304,
#  226,
#  2192,
#  844,
#  8497,
#  9182,
#  853,
#  245,
#  4430,
#  1264,
#  144,
#  4938,
#  3572,
#  8392,
#  6304,
#  9945,
#  1086,
#  1593,
#  207,
#  701,
#  5104,
#  3048,
#  3534,
#  758,
#  198,
#  9823,
#  3605,
#  1322,
#  9822,
#  8498,
#  3829,
#  709,
#  956,
#  8300,
#  10230,
#  670,
#  1044,
#  1048,
#  897,
#  849,
#  801,
#  780,
#  28,
#  3869,
#  2938,
#  2887,
#  7865,
#  1771,
#  1087,
#  8728,
#  4283,
#  10490,
#  499,
#  1373,
#  989,
#  3970,
#  1040,
#  3588,
#  4523,
#  737,
#  1017,
#  2137,
#  4258,
#  123,
#  1238,
#  442,
#  11757,
#  3541,
#  10559,
#  12218,
#  4955,
#  3538,
#  5532,
#  9818,
#  3537,
#  8052,
#  371,
#  4052,
#  7937,
#  1228,
#  11956,
#  2610,
#  2215,
#  12021,
#  2784,
#  3175,
#  3183,
#  6162,
#  414,
#  1223,
#  535,
#  1159,
#  1530,
#  9471,
#  547,
#  835,
#  794,
#  1880,
#  11792,
#  259,
#  6482,
#  991,
#  6629,
#  567,
#  6573,
#  9764,
#  1843,
#  11933,
#  3828,
#  2143,
#  12642,
#  9765,
#  1434,
#  1640,
#  9824,
#  4397,
#  11439,
#  1505,
#  3496,
#  3810,
#  5329,
#  2766,
#  493,
#  1684,
#  3586,
#  2385,
#  1682,
#  6256,
#  6645,
#  252,
#  12265,
#  3182,
#  7641,
#  1550,
#  3178,
#  7643,
#  6794,
#  3176,
#  12022,
#  2548,
#  124,
#  12219,
#  1847,
#  698,
#  1248,
#  3174,
#  8506,
#  1136,
#  1079,
#  1734,
#  3177,
#  7800,
#  546,
#  2166,
#  2495,
#  8450,
#  8397,
#  4530,
#  1084,
#  3543,
#  3883,
#  658,
#  3181,
#  196,
#  7640,
#  388,
#  279,
#  3545,
#  8307,
#  3790,
#  6900,
#  3173,
#  962,
#  8501,
#  9472,
#  3658,
#  2197,
#  887,
#  3555,
#  4920,
#  4300,
#  10533,
#  6576,
#  3925,
#  8505,
#  11934,
#  11469,
#  3542,
#  1790,
#  2608,
#  957,
#  4261,
#  3882,
#  8508,
#  8500,
#  2458,
#  2138,
#  3547,
#  11798,
#  11614,
#  1965,
#  7642,
#  680,
#  8504,
#  1080,
#  8308,
#  2006,
#  1247,
#  1039,
#  1212,
#  11499,
#  10691,
#  4711,
#  1767,
#  11691,
#  4079,
#  9473,
#  3831,
#  3184,
#  2208,
#  1642,
#  368,
#  7894,
#  2204,
#  3179,
#  960,
#  3180,
#  6445,
#  1835,
#  569,
#  683,
#  9825,
#  5939,
#  12639,
#  10362,
#  3187,
#  4411,
#  8306,
#  3599,
#  3535,
#  8235,
#  963,
#  12092,
#  3552,
#  6824,
#  6795,
#  95,
#  628,
#  7895,
#  7255,
#  958,
#  12041,
#  2362,
#  7644,
#  7188,
#  1423,
#  6049,
#  377,
#  3653,
#  3651,
#  425,
#  5693,
#  1387,
#  2640,
#  3554,
#  6796,
#  3652,
#  2199,
#  2755,
#  814,
#  11440,
#  961,
#  10110,
#  4613,
#  907,
#  12638,
#  9745,
#  728,
#  12220,
#  9972,
#  344,
#  766,
#  8826,
#  8237,
#  1366,
#  4273,
#  1041,
#  8711,
#  1273,
#  1455,
#  2272,
#  1973,
#  3551,
#  896,
#  1469,
#  9827,
#  7334,
#  3259,
#  3540,
#  607,
#  8305,
#  10,
#  1972,
#  3560,
#  2430,
#  7286,
#  899,
#  2489,
#  8462,
#  3557,
#  8238,
#  1964,
#  392,
#  1278,
#  283,
#  8499,
#  2213,
#  4340,
#  4046,
#  870,
#  2892,
#  2141,
#  11738,
#  978,
#  10537,
#  892,
#  3597,
#  1870,
#  6798,
#  1426,
#  2609,
#  4620,
#  358,
#  8310,
#  8236,
#  3275,
#  1613,
#  1025,
#  964,
#  10092,
#  9429,
#  3706,
#  9727,
#  774,
#  3234,
#  9826,
#  6363,
#  788,
#  5778,
#  147,
#  6444,
#  8015,
#  1634,
#  3609,
#  3333,
#  4263,
#  3779,
#  3657,
#  3185,
#  8502,
#  3252,
#  2200,
#  8048,
#  891,
#  4956,
#  9828,
#  1323,
#  639,
#  3559,
#  318,
#  5010,
#  1981,
#  6483,
#  6253,
#  1532,
#  1846,
#  3186,
#  268,
#  2520,
#  1966,
#  3549,
#  4721,
#  3008,
#  4720,
#  1083,
#  8002,
#  343,
#  3550,
#  1943,
#  959,
#  7801,
#  2806,
#  12026,
#  5322,
#  422,
#  2384,
#  550,
#  351,
#  10212,
#  1424,
#  2380,
#  519,
#  3188,
#  1796,
#  1001,
#  3,
#  66,
#  2377,
#  1737,
#  2850,
#  261,
#  3558,
#  5632,
#  9639,
#  3097,
#  11878,
#  5193,
#  6934,
#  2575,
#  1842,
#  9427,
#  7256,
#  661,
#  10363,
#  2091,
#  2824,
#  1956,
#  9829,
#  537,
#  9433,
#  9430,
#  330,
#  10111,
#  2021,
#  3807,
#  4113,
#  2087,
#  5694,
#  8572,
#  8161,
#  3600,
#  10138,
#  7474,
#  7587,
#  2288,
#  632,
#  4944,
#  1646,
#  2638,
#  2092,
#  847,
#  9440,
#  1975,
#  8116,
#  8573,
#  5076,
#  4605,
#  8239,
#  789,
#  4926,
#  4928,
#  1969,
#  12027,
#  5009,
#  901,
#  37,
#  3926,
#  1968,
#  6797,
#  3210,
#  131,
#  4774,
#  3244,
#  501,
#  664,
#  4116,
#  3343,
#  3631,
#  1024,
#  4102,
#  936,
#  2196,
#  1030,
#  1489,
#  2209,
#  8309,
#  4013,
#  3310,
#  2534,
#  12288,
#  9640,
#  5217,
#  8899,
#  1101,
#  5981,
#  795,
#  1026,
#  1554,
#  9438,
#  1359,
#  1619,
#  9432,
#  9952,
#  3700,
#  2660,
#  6928,
#  9953,
#  5258,
#  4112,
#  9262,
#  6853,
#  6128,
#  10587,
#  1344,
#  8516,
#  4953,
#  918,
#  1886,
#  7040,
#  1430,
#  3061,
#  6213,
#  5740,
#  10692,
#  4679,
#  10862,
#  8854,
#  5094,
#  5294,
#  6801,
#  4886,
#  2194,
#  11936,
#  11511,
#  4117,
#  1643,
#  657,
#  2531,
#  624,
#  2346,
#  9973,
#  4120,
#  6646,
#  1869,
#  12030,
#  3076,
#  2183,
#  2606,
#  10588,
#  9183,
#  9439,
#  1091,
#  1644,
#  4934,
#  11442,
#  12289,
#  8884,
#  4927,
#  843,
#  6804,
#  919,
#  9491,
#  11692,
#  9428,
#  11512,
#  542,
#  5848,
#  3708,
#  7588,
#  6105,
#  1251,
#  3045,
#  3364,
#  7103,
#  2185,
#  6485,
#  1031,
#  8574,
#  6103,
#  2808,
#  2007,
#  9954,
#  4915,
#  1912,
#  2363,
#  869,
#  7997,
#  4516,
#  9323,
#  290,
#  12032,
#  3544,
#  1979,
#  1279,
#  2666,
#  2712,
#  736,
#  2127,
#  734,
#  6095,
#  4140,
#  11899,
#  714,
#  1236,
#  1892,
#  8024,
#  9766,
#  11025,
#  2360,
#  1486,
#  916,
#  2280,
#  2741,
#  7657,
#  739,
#  10259,
#  3595,
#  ...]

# %%
user_taggedartists[user_taggedartists['tagID'].isin(b[b>100].keys())].shape
# Out:
# (136523, 6)

# %%
tags[tags['tagID'].isin(b[b>0].keys())].shape
# Out:
# (9437, 2)

# %%
class Evaluation(RecommenderSystem):
    
    def save_edges(self, referenceNode, listOfNodes):
        edges = []
        for node in listOfNodes:
            edges.append((referenceNode, node, self._graph.get_edge_data(referenceNode, node)))
        return edges
    
    def user_recommendation_evaluation(self, referenceUser, maxReferenceArtists=3, recommendationLength=10, relevanceLength=10, kneighborhood=None, maxSimilarUsers=5):
        '''Evaluates the recommendation of a user'''
        
        # We get the most relevant artists from the reference user apart from the ones chosen for the recommendation
        referenceUserArtists = set(self.get_kdistant_neighbors_by_type(referenceUser, type='ua'))
        referenceArtists = self.get_relevant_artists_from_user(referenceUser, referenceUserArtists)
        if maxReferenceArtists >= len(referenceArtists):
            print 'There are not enough relevant artists to evaluate the recommendation'
            return -1
        relevantArtists = set(referenceArtists[maxReferenceArtists:min(maxReferenceArtists+relevanceLength,len(referenceArtists)-1)])
        
        # We remove the edges of the reference user not used as a basis for the recommendation
        nodeConnectionsToRemove = referenceArtists[min(maxReferenceArtists,len(referenceArtists)-1):]
        connections = self.save_edges(referenceUser, nodeConnectionsToRemove)
        self._graph.remove_edges_from(connections)
        
        # We get the recommendation of the user considering only their 'maxReferenceArtists' most listened artists
        recommendedArtists = self.recommendation(referenceUser, maxReferenceArtists=maxReferenceArtists, kneighborhood=kneighborhood, maxSimilarUsers=maxSimilarUsers)
        # We keep the most similar artists found in the recommendation
        recommendedArtists = set([recommendedArtists[i][0] for i in range(min(recommendationLength, len(recommendedArtists)))]) 
        
        # We check how many of these relevant artists the recommendation is able to recover
        recoveredArtists = relevantArtists.intersection(recommendedArtists)
        
        #print len(recoveredArtists)
        #print recommendedArtists
        #print relevantArtists
        
        # We recover the removed connections for the evaluation
        self._graph.add_edges_from(connections)
        
        return len(recoveredArtists)
    
    def recommendation_evaluation(self, maxReferenceArtists=3, recommendationLength=10, relevanceLength=10, kneighborhood=None, maxSimilarUsers=5, l=10):
        recoveries = []
        for user in self.users_id[0:min(l,len(self.users_id))]:
            recoveries.append(self.user_recommendation_evaluation(self.key_user(user), maxReferenceArtists=maxReferenceArtists, recommendationLength=recommendationLength, relevanceLength=relevanceLength, kneighborhood=kneighborhood, maxSimilarUsers=maxSimilarUsers))
        plt.plot(recoveries)
        plt.title('Relevant artists recovered')
        plt.show()
        return recoveries

# %%
import numpy as np
from matplotlib.ticker import MaxNLocator

x = [0,0,1,1,1,1,2,2,3]
ax = plt.figure().gca()
plt.xticks(range(np.min(x), np.max(x)+1))
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.hist(x, range=(np.min(x)-0.5, np.max(x)+0.5), bins=np.max(x)+1)
plt.show()

# %% [markdown]
# # Recommender System

# %%
from recommender_system import RecommenderSystem
r = RecommenderSystem.instance()
r.recommendation('u_1814')

# %%
from lastfm_network import *

class RecommenderSystem(LastfmNetwork):
    
    def recommendation(self, referenceUser, kneighborhood=None, maxSimilarUsers=5):
        '''recommender script: given a userID, retrieves the recommended artists'''
        
        # We create dictionaries to move between node IDs and indices of similarity matrices
        self.node2indexUserDict = {user: idx for idx,user in enumerate(self.users_iter())}
        self.node2indexArtistDict = {artist: idx for idx,artist in enumerate(self.artists_iter())}
        
        # If requested, we only get the user k-neighborhood. If not, we consider all users.
        if kneighborhood:
            consideredUsers = self.get_kdistant_neighbors_by_type(referenceUser, k=kneighborhood)
            if len(consideredUsers)==0:
                return 'Impossible to make a recommendation based on the social neighborhood: the user has no friendship relations'
        else: 
            consideredUsers = [user for user in self.users_iter()]
            consideredUsers.remove(referenceUser)
        
        # We get the similarities of all considered users with respect to the reference one in descending order
        similarUsers = self.get_user_similarities(referenceUser, consideredUsers)
        # We only keep up to a maxSimilarUsers number of users for the recommendation
        similarUsers = [similarUser[0] for similarUser in similarUsers[:min(len(similarUsers),maxSimilarUsers)]]
        
        # We get the artists that the reference user has listened to
        referenceUserArtists = set(self.get_kdistant_neighbors_by_type(referenceUser, type='ua'))
        # We select as relevant those artists with a high number of reproductions by the reference user
        referenceArtists = self.get_relevant_artists_from_user(referenceUser, referenceUserArtists)
        
        # We look for the candidate artist list considering all similar users found
        candidateArtistList = []
        for similarUser in similarUsers:
            # The candidate artists come from the artists listened by a similar user but not by the reference one
            # We only keep those candidates that we consider relevant for the similar user
            candidateArtists = self.get_candidate_artists_from_similar_user(similarUser, referenceUser, referenceUserArtists)
            
            # We get the maximum similarity score of each candidate with respect to the 
            # relevant artists of the reference user
            candidateArtists = self.get_scores_for_candidate_artists(referenceArtists, candidateArtists)
            
            # We combine these candidates with the previously found ones
            candidateArtistList = self.combine_lists_of_candidate_artists(candidateArtistList, candidateArtists)
            
        candidateArtistList = sorted(candidateArtistList, key=self.get_ordering_key, reverse=True)
        return candidateArtistList
    
    def get_kdistant_neighbors_by_type(self, centralNode, type='uu', k=1):
        '''return the neighbors of a node up to a distance k 
        specifying the kind of edges to consider'''
        nodesToExplore = [centralNode]
        neighbors = [] 
        for _ in range(k):
            newNeighbors = []
            for node in nodesToExplore:
                newNeighbors += [x for x in self._graph.neighbors(node) 
                                 if self._graph.get_edge_data(node,x)['type']==type 
                                 and x not in neighbors+[centralNode]]
            neighbors += newNeighbors
            nodesToExplore = newNeighbors
        return neighbors
    
    def get_user_user_similarity(self, node1, node2):
        '''given two userIDs, return the computed similarity between them'''
        idx1, idx2 = self.node2indexUserDict[node1], self.node2indexUserDict[node2]
        if idx1 > idx2:
            return self.user_similarities[idx1, idx2]
        else:
            return self.user_similarities[idx2, idx1]

    def get_artist_artist_similarity(self, node1, node2):
        '''given two artistIDs, return the computed similarity between them'''
        idx1, idx2 = self.node2indexArtistDict[node1], self.node2indexArtistDict[node2]
        if idx1 > idx2:
            return self.artist_similarities_tags[idx1, idx2]
        else:
            return self.artist_similarities_tags[idx2, idx1]

    def get_ordering_key(self, element):
        '''usefut function for obtaining the ordering key of lists of tuples'''
        return element[1]
    
    def get_user_similarities(self, centralNode, listOfNodes):
        '''given a reference user and a list of users, computes the similarity 
        of each element of the list with respect to the reference user'''
        userSim = [(node, self.get_user_user_similarity(centralNode, node)) for node in listOfNodes]
        return sorted(userSim, key=self.get_ordering_key, reverse=True)
    
    def get_artist_similarities(self, centralNode, listOfNodes):
        '''given a reference artist and a list of artists, computes the similarity 
        of each element of the list with respect to the reference artist'''
        artistSim = [(node, self.get_artist_artist_similarity(centralNode, node)) for node in listOfNodes]
        return sorted(artistSim, key=self.get_ordering_key, reverse=True)

    def get_relevant_artists_from_user(self, user, userArtists, maxAccum=0.9):
        '''Retrieves the most listened artists'''
        weightedUserArtists = [(artist, self._graph.get_edge_data(user,artist)['norm_weight']) 
                               for artist in userArtists]
        relevantArtists, accum = [], 0.
        for artist, weight in sorted(weightedUserArtists, key=self.get_ordering_key, reverse=True):
            relevantArtists += [artist]
            accum += weight
            if accum > maxAccum:
                break;
        return relevantArtists

    def get_candidate_artists_from_similar_user(self, similarUser, referenceUser, referenceUserArtists):
        '''Gets the relevant candidate artists from a similar user'''
        # We get the artists that the similar user has listened to
        similarUserArtists = set(self.get_kdistant_neighbors_by_type(similarUser, type='ua'))
        # The candidate artists come from the difference with respect to the ones that the reference user has listened to
        candidateArtists = similarUserArtists.difference(referenceUserArtists)
        # We return the candidates that we consider relevant for the similar user
        relevantSimilarUserArtists = set(self.get_relevant_artists_from_user(similarUser, similarUserArtists))
        return list(candidateArtists.intersection(relevantSimilarUserArtists))
    
    def get_scores_for_candidate_artists(self, referenceArtists, candidateArtists):
        '''Retrieves for each candidate artist the maximum similarity score with respect to any 
        reference artist'''
        return [(artist, self.get_artist_similarities(artist, referenceArtists)[0][1]) 
                for artist in candidateArtists]

    def combine_lists_of_candidate_artists(self, list1, list2):
        '''Combine lists of candidate artists avoiding repetitions'''
        return list(set(list1+list2))

# %% [markdown]
# ### - Tests Recommender System

# %%
def get_kdistant_neighbors_by_type(G, centralNode, type='uu', k=1):
    '''return the neighbors of a node up to a distance k 
    specifying the kind of edges to consider'''
    nodesToExplore = [centralNode]
    neighbors = [] 
    for _ in range(k):
        newNeighbors = []
        for node in nodesToExplore:
            newNeighbors += [x for x in G.neighbors(node) 
                             if G.get_edge_data(node,x)['type']==type 
                             and x not in neighbors+[centralNode]]
        neighbors += newNeighbors
        nodesToExplore = newNeighbors
    return neighbors

def get_user_user_similarity(node1, node2):
    '''given two userIDs, return the computed similarity between them'''
    idx1, idx2 = node2indexUserDict[node1], node2indexUserDict[node2]
    if idx1 > idx2:
        return r.user_similarities[idx1, idx2]
    else:
        return r.user_similarities[idx2, idx1]

def get_artist_artist_similarity(node1, node2):
    '''given two artistIDs, return the computed similarity between them'''
    idx1, idx2 = node2indexArtistDict[node1], node2indexArtistDict[node2]
    if idx1 > idx2:
        return r.artist_similarities_users[idx1, idx2]
    else:
        return r.artist_similarities_users[idx2, idx1]

def get_ordering_key(element):
    return element[1]

def get_user_similarities(centralNode, listOfNodes=None):
    if not listOfNodes:
        listOfNodes = [node for node in r.users_iter()]
        listOfNodes.remove(centralNode)
    userSim = [(node, get_user_user_similarity(centralNode, node)) for node in listOfNodes]
    return sorted(userSim, key=get_ordering_key, reverse=True)

def get_artist_similarities(centralNode, listOfNodes):
    artistSim = [(node, get_artist_artist_similarity(centralNode, node)) for node in listOfNodes]
    return sorted(artistSim, key=get_ordering_key, reverse=True)

def get_candidate_artists_from_similar_user(originalUser, similarUser):
    # make originalUserArtists a class variable
    originalUserArtists = set(get_kdistant_neighbors_by_type(r._graph, originalUser, type='ua'))
    similarUserArtists = set(get_kdistant_neighbors_by_type(r._graph, similarUser, type='ua'))
    return list(similarUserArtists.difference(originalUserArtists))

def get_relevant_artists_from_user(user, maxAccum=0.75):
    # consider to pass userArtists as an argument
    userArtists = get_kdistant_neighbors_by_type(r._graph, user, type='ua')
    weightedUserArtists = [(artist, r._graph.get_edge_data(user,artist)['norm_weight']) 
                           for artist in userArtists]
    relevantArtists, accum = [], 0.
    for artist, weight in sorted(weightedUserArtists, key=get_ordering_key, reverse=True):
        relevantArtists += [artist]
        accum += weight
        if accum > maxAccum:
            break;
    return relevantArtists

def get_scores_for_candidate_artists(referenceArtists, candidateArtists):
    return [(artist, get_artist_similarities(artist, referenceArtists)[0][1]) 
            for artist in candidateArtists]

def combine_lists_of_candidate_artists(list1, list2):
    candidateDict = {artist: score for artist,score in list1}
    for artist,score in list2:
        if artist in candidateArtists.keys():
            candidateDict[artist] = max(candidateDict[artist], score)
        else:
            candidateArtist[artist] = score
    return [(artist, candidateDict[artist]) for artist in candidateDict]

# %%
node2indexUserDict = {user: idx for idx,user in enumerate(r.users_iter())}
node2indexArtistDict = {artist: idx for idx,artist in enumerate(r.artists_iter())}

# %%
a = [user for user in r.users_iter()][0:10]
get_user_similarities('u_1210', a)

# %%
get_candidate_artists_from_similar_user('u_1210', 'u_1200')[0:3]

# %%
get_relevant_artists_from_user('u_2')

# %% [markdown]
# # Evaluator
